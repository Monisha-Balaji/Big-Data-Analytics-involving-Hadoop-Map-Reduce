# %% [markdown]
# ## Twitter Data Collection using R

# %% [markdown]
# ## Importing R Packages

# %% [markdown]
# Inorder to help with the efficient running of our R scripts, it is essential to install the necessary packages to help support the corresponding functions that help with data manipulation. Here, the packages installed are:
# 1. rtweet - Supports the basic R functionalities for twitter
# 2. usmap - Allows plotting the map of USA
# 3. dplyr - Helps with manipulation and working with dataframes i.e filter(), select()
# 4. tidyverse - Helps with the easy installation and loading of other 'tidyverse' packages
# 5. gridExtra - Aids to work with grid-based plots and drawing tables

# %%
library(rtweet)

# %%
library(dplyr)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.5.2"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
library(tidyverse)

# %%
library(gridExtra)
# Out:
# Warning message:
# "package 'gridExtra' was built under R version 3.5.2"
# Attaching package: 'gridExtra'
#
# The following object is masked from 'package:dplyr':
#
#     combine

# %% [markdown]
# ## TWEET COLLECTION

# %% [markdown]
# Here, we have used the rtweet package to help with Twitter data collection and processing. It allows the use of functions which after the authentication of your twitter key credentials, helps collect streaming tweets using the Twitter Search API.

# %%
token <-create_token(
  app = "InforRetrieve",
  consumer_key = "0c5eBmUITQrogjSnjuiehM9yY",
  consumer_secret = "Yr3QNybP0o4kMTVunc51Vzh9ls4Pxqr2yPBIoHJpuaYtdgrRc7",
  access_token = "1037053231921287168-NHdImTN3T8CblmbiVBMWljXL3d3jly",
  access_secret = "vAwqG5mLf9GaKwoSn4TMWg9AmUN4ZDRnHIuwvFgsRm3vH")

# %%
theft <- search_tweets("theft", geocode = lookup_coords("usa"), n = 10000, include_rts = FALSE)
# Out:
# Searching for tweets...
# Finished collecting tweets!

# %%
robbery <- search_tweets("robbery", geocode = lookup_coords("usa"), n = 10000, include_rts = FALSE)
# Out:
# Searching for tweets...
# Warning message:
# "Rate limit exceeded - 88"Warning message:
# "Rate limit exceeded"Finished collecting tweets!

# %%
rape <- search_tweets("rape", geocode = lookup_coords("usa"), n = 10000, include_rts = FALSE)
# Out:
# Searching for tweets...
# Finished collecting tweets!

# %%
murder <- search_tweets("murder", geocode = lookup_coords("usa"), n = 10000, include_rts = FALSE)
# Out:
# Searching for tweets...
# Warning message:
# "Rate limit exceeded - 88"Warning message:
# "Rate limit exceeded"Finished collecting tweets!

# %%
terror <- search_tweets("terrorism", geocode = lookup_coords("usa"), n = 10000, include_rts = FALSE)
# Out:
# Searching for tweets...
# Finished collecting tweets!

# %%
dim(terror)
# Out:
# [1] 9626   88

# %%
colnames(murder)
# Out:
#  [1] "user_id"                 "status_id"
#  [3] "created_at"              "screen_name"
#  [5] "text"                    "source"
#  [7] "display_text_width"      "reply_to_status_id"
#  [9] "reply_to_user_id"        "reply_to_screen_name"
# [11] "is_quote"                "is_retweet"
# [13] "favorite_count"          "retweet_count"
# [15] "hashtags"                "symbols"
# [17] "urls_url"                "urls_t.co"
# [19] "urls_expanded_url"       "media_url"
# [21] "media_t.co"              "media_expanded_url"
# [23] "media_type"              "ext_media_url"
# [25] "ext_media_t.co"          "ext_media_expanded_url"
# [27] "ext_media_type"          "mentions_user_id"
# [29] "mentions_screen_name"    "lang"
# [31] "quoted_status_id"        "quoted_text"
# [33] "quoted_created_at"       "quoted_source"
# [35] "quoted_favorite_count"   "quoted_retweet_count"
# [37] "quoted_user_id"          "quoted_screen_name"
# [39] "quoted_name"             "quoted_followers_count"
# ...

# %% [markdown]
# ## BINDING TWEETS TOGETHER

# %%
combo = bind_rows(theft,robbery)

# %%
combo = bind_rows(combo,rape)

# %%
combo = bind_rows(combo,murder)

# %%
combo = bind_rows(combo,terror)

# %% [markdown]
# ## EXTRACTING ONLY THE ESSENTIAL COLUMNS

# %%
tweets <-select(combo, user_id, status_id, created_at, screen_name, text, location ,source,retweet_count,lang, verified,country,country_code,url )

# %%
write.csv(tweets, file="diclab2_tweets.csv")

# %% [markdown]
# CHECKING FOR DUPLICATES

# %%
duplicated(tweets)
# Out:
#     [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [73] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [85] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [97] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [109] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [121] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [133] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %%
dim(tweets)
# Out:
# [1] 44516    13
